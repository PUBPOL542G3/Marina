# %%
#link='marinaData.xls'

# %%
import pandas as pd
Forest='https://github.com/PUBPOL542G3/Marina/raw/main/FAOSTAT_data_1-21-2021.xls'
marina=pd.read_excel(Forest)

# %%
marina
# Out:
#      Domain Code       Domain  Area Code         Area  Element Code Element  \
# 0             GF  Forest Land          2  Afghanistan          5110    Area
# 1             GF  Forest Land          2  Afghanistan          5110    Area
# 2             GF  Forest Land          2  Afghanistan          5110    Area
# 3             GF  Forest Land          2  Afghanistan          5110    Area
# 4             GF  Forest Land          2  Afghanistan          5110    Area
# ...          ...          ...        ...          ...           ...     ...
# 4889          GF  Forest Land        181     Zimbabwe          5110    Area
# 4890          GF  Forest Land        181     Zimbabwe          5110    Area
# 4891          GF  Forest Land        181     Zimbabwe          5110    Area
# 4892          GF  Forest Land        181     Zimbabwe          5110    Area
# 4893          GF  Forest Land        181     Zimbabwe          5110    Area
#
# ...

# %%
marina.pivot(index='Area', columns='Year', values='Value')
# Out:
# Year                           2000       2001       2002       2003  \
# Area
# Afghanistan                 1208.44   1208.440   1208.440   1208.440
# Albania                      769.30    770.577    771.854    773.131
# Algeria                     1579.00   1612.900   1646.800   1680.700
# American Samoa                17.73     17.700     17.670     17.640
# Andorra                       16.00     16.000     16.000     16.000
# ...                             ...        ...        ...        ...
# Wallis and Futuna Islands      5.81      5.811      5.812      5.813
# Western Sahara               669.31    668.890    668.470    668.050
# Yemen                        549.00    549.000    549.000    549.000
# Zambia                     47054.00  47018.200  46982.400  46946.600
# Zimbabwe                   18365.98  18319.910  18273.840  18227.770
#
# Year                            2004       2005       2006       2007  \
# Area
# ...

# %%
marinawide1=marina.pivot(index='Area', columns='Year', values='Value')

# %%
marina.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Flag Description'],
#       dtype='object')

# %%
marina.columns[:8].append(marina.columns[12:])
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
marina.columns[:8].append(marina.columns[12:]).to_list()
# Out:
# ['Domain Code',
#  'Domain',
#  'Area Code',
#  'Area',
#  'Element Code',
#  'Element',
#  'Item Code',
#  'Item',
#  'Flag',
#  'Flag Description']

# %%
indexes=marina.columns[:8].append(marina.columns[12:]).to_list()

# %%
marina.pivot(index=indexes, columns='Year', values='Value').reset_index()
# Out:
# Year Domain Code       Domain  Area Code                        Area  \
# 0             GF  Forest Land          1                     Armenia
# 1             GF  Forest Land          2                 Afghanistan
# 2             GF  Forest Land          3                     Albania
# 3             GF  Forest Land          4                     Algeria
# 4             GF  Forest Land          5              American Samoa
# ..           ...          ...        ...                         ...
# 233           GF  Forest Land        280   Sint Maarten (Dutch part)
# 234           GF  Forest Land        281  Saint-Martin (French part)
# 235           GF  Forest Land        283                      Jersey
# 236           GF  Forest Land        299                   Palestine
# 237           GF  Forest Land        351                       China
#
# Year  Element Code Element  Item Code         Item Flag  \
# 0             5110    Area       6646  Forest land    F
# ...

# %%
marinawide2=marina.pivot(index=indexes, columns='Year', values='Value').reset_index()

# %%
marinawide2
# Out:
# Year Domain Code       Domain  Area Code                        Area  \
# 0             GF  Forest Land          1                     Armenia
# 1             GF  Forest Land          2                 Afghanistan
# 2             GF  Forest Land          3                     Albania
# 3             GF  Forest Land          4                     Algeria
# 4             GF  Forest Land          5              American Samoa
# ..           ...          ...        ...                         ...
# 233           GF  Forest Land        280   Sint Maarten (Dutch part)
# 234           GF  Forest Land        281  Saint-Martin (French part)
# 235           GF  Forest Land        283                      Jersey
# 236           GF  Forest Land        299                   Palestine
# 237           GF  Forest Land        351                       China
#
# Year  Element Code Element  Item Code         Item Flag  \
# 0             5110    Area       6646  Forest land    F
# ...

# %%
#bye=['Domain Code','Domain'] -- why doesn't this work?
#marinawide2.drop(columns=bye,inplace=True)

#marinawide2.drop(marinawide2.iloc[:,1:25], inplace=True, axis =1)
#marinawide2.drop(marinawide2.iloc[:,4:8], inplace=True, axis =1)
#marinawide2

for col in marinawide2.columns:
    print(col)
    if col == 'Area' or col == 2015:
        print('Dont drop it')
    else:
        marinawide2.drop(columns=col,inplace=True)
        print(' Drop it')
# Out:
# Domain Code
#  Drop it
# Domain
#  Drop it
# Area Code
#  Drop it
# Area
# Dont drop it
# Element Code
#  Drop it
# Element
#  Drop it
# Item Code
#  Drop it
# Item
#  Drop it
# Flag
#  Drop it
# Flag Description
#  Drop it
# 2000
#  Drop it
# 2001
#  Drop it
# 2002
#  Drop it
# 2003
#  Drop it
# 2004
#  Drop it
# 2005
#  Drop it
# 2006
#  Drop it
# 2007
#  Drop it
# 2008
#  Drop it
# 2009
#  Drop it
# 2010
#  Drop it
# 2011
#  Drop it
# 2012
#  Drop it
# 2013
#  Drop it
# 2014
#  Drop it
# 2015
# Dont drop it
# 2016
#  Drop it
# 2017
#  Drop it
# 2018
#  Drop it
# 2019
#  Drop it
# 2020
#  Drop it

# %%
marinawide2.rename(columns={2015:'Forested Area'},inplace=True)
marinawide2.rename(columns={'Area':'country'},inplace=True)
marinawide2
# Out:
# Year                     country  Forested Area
# 0                        Armenia       329.5200
# 1                    Afghanistan      1208.4400
# 2                        Albania       789.1875
# 3                        Algeria      1956.0000
# 4                 American Samoa        17.2800
# ..                           ...            ...
# 233    Sint Maarten (Dutch part)         0.3700
# 234   Saint-Martin (French part)         1.2400
# 235                       Jersey         0.6000
# 236                    Palestine        10.1400
# 237                        China    210294.2500
#
# [238 rows x 2 columns]

# %%
#marinawide2.to_excel('marina.xlsx')
marinawide2.to_excel(r'/Users/MarinaKaminsky/Downloads/marina.xlsx', sheet_name='Forested Area', index = False)

# %%
locationfor= 'https://github.com/PUBPOL542G3/pythondeliverable-/blob/main/marina.xlsx'
#marina5 = pd.read_excel(location)
#CO2file=location+'co2_emissions_tonnes_per_person.xlsx'
#Nur=pd.read_excel(CO2file)
#marina.merge(Nur,left_on='Area',right_on='country',how='left')

# %%
#pd.read_excel(locationfor)
#pd.read_excel('https://github.com/PUBPOL542G3/pythondeliverable-/blob/main/marina.xlsx')
pd.read_excel('https://github.com/kaminsma/Computational-Think-PUBPOL-542/blob/main/marina.xlsx')
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-19-6a9ed0aea440> in <module>
#       1 #pd.read_excel(locationfor)
#       2 #pd.read_excel('https://github.com/PUBPOL542G3/pythondeliverable-/blob/main/marina.xlsx')
# ----> 3 pd.read_excel('https://github.com/kaminsma/Computational-Think-PUBPOL-542/blob/main/marina.xlsx')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ...

# %%
marinawide3 = marinawide2.replace({
     "Bolivia (Plurinational State of)":"Bolivia",
    'Brunei Darussalam': 'Brunei',
    'Cabo Verde': 'Cape Verde',
    'Congo': 'Republic of the Congo',
    "Côte d'Ivoire":"Cote d'Ivoire",
    'Czechia': 'Czech Republic',
    "Democratic People's Republic of Korea": 'South Korea',
    'Iran (Islamic Republic of)': 'Iran',
    "Lao People's Democratic Republic":'Lao',
    'Micronesia (Federated States of)': 'Micronesia, Fed. Sts.',
    'Republic of Korea': 'North Korea',
    'Republic of Moldova': 'Moldova',
    'Russian Federation':'Russia',
    'Saint Kitts and Nevis':'St. Kitts and Nevis',
    'Saint Lucia':'St. Lucia',
    'Saint Vincent and the Grenadines':'St. Vincent and the Grenadines',
    'Syrian Arab Republic':'Syria',
    'United Kingdom of Great Britain and Northern Ireland':'United Kingdom',
    'United Republic of Tanzania':'Tanzania',
    'United States of America':'United States',
    'Venezuela (Bolivarian Republic of)':'Venezuela',
    'Viet Nam':'Vietnam'
})
display(marinawide3)
# Out:
# Year                     country  Forested Area
# 0                        Armenia       329.5200
# 1                    Afghanistan      1208.4400
# 2                        Albania       789.1875
# 3                        Algeria      1956.0000
# 4                 American Samoa        17.2800
# ..                           ...            ...
# 233    Sint Maarten (Dutch part)         0.3700
# 234   Saint-Martin (French part)         1.2400
# 235                       Jersey         0.6000
# 236                    Palestine        10.1400
# 237                        China    210294.2500
#
# [238 rows x 2 columns]

# %%
marinawide3.to_excel(r'/Users/MarinaKaminsky/Desktop/marina.xlsx', sheet_name='Forested Area', index = False)
